# %%
import math
import numpy as np
import pandas as pd

# %%
filename = "../data/test_data.txt"
my_data = np.genfromtxt(filename, delimiter=',')
# df = pd.read_csv(filename,header=None,names=["data"])
# print(df)
# print(my_data)

# %%
def combination_test(pream,flag,test_val,pream_count):
    for preamble_iter1 in pream:
#         print(preamble_iter1)
#         print(len(pream))
        for preamble_iter2 in pream:
#             print(preamble_iter2)
            if preamble_iter2 == preamble_iter1:
                print("element1 : {},element2: {}, No sum".format(preamble_iter1,preamble_iter2))
                pass
            else:
                element_sum = preamble_iter1 + preamble_iter2
                print("element1 : {},element2 : {}, test value: {}, sum : {}".format(preamble_iter1,preamble_iter2,test_val,element_sum))
                if test_val==element_sum:
                    flag=1
        if preamble_iter1 == pream[pream_count-1] and flag==0:
            flagged_val=test_val
            print("here1")   
        else:
            flagged_val=0
            print("here2")   
        return(flag,flagged_val)


preamble_count = 5
flag=0


# for i in enumerate(my_data):
#     preamble = my_data[i[0]:i[0]+preamble_count]
# #     print(preamble)
#     test_val = my_data[i[0]+preamble_count+1]
# #     print("new loop")
#     flag=0
#     for j in preamble:
# #         print(j)
# #         print(len(preamble))
#         for k in preamble:
# #             print(k)
#             if k==j:
# #                 print("element1 : {},element2: {}, No sum".format(k,j))
#                 pass
#             else:
#                 p=j+k
# #                 print("element1 : {},element2 : {}, test value: {}, sum : {}".format(k,j,test_val,p))
#                 if test_val==p:
#                     flag=1
# #                     print(flag)
#     if j == preamble[preamble_count-1] and flag==0:
#         print(test_val)

for i in enumerate(my_data):
    preamble = my_data[i[0]:i[0]+preamble_count]
#     print(preamble)
    test_val = my_data[i[0]+preamble_count+1]
#     print("new loop")
    flag=0
    flag,value=combination_test(preamble,flag,test_val,preamble_count)
    print(value)
# Out:
# element1 : 35.0,element2: 35.0, No sum
# element1 : 35.0,element2 : 20.0, test value: 62.0, sum : 55.0
# element1 : 35.0,element2 : 15.0, test value: 62.0, sum : 50.0
# element1 : 35.0,element2 : 25.0, test value: 62.0, sum : 60.0
# element1 : 35.0,element2 : 47.0, test value: 62.0, sum : 82.0
# here2
# 0
# element1 : 20.0,element2: 20.0, No sum
# element1 : 20.0,element2 : 15.0, test value: 55.0, sum : 35.0
# element1 : 20.0,element2 : 25.0, test value: 55.0, sum : 45.0
# element1 : 20.0,element2 : 47.0, test value: 55.0, sum : 67.0
# element1 : 20.0,element2 : 40.0, test value: 55.0, sum : 60.0
# here2
# 0
# element1 : 15.0,element2: 15.0, No sum
# element1 : 15.0,element2 : 25.0, test value: 65.0, sum : 40.0
# element1 : 15.0,element2 : 47.0, test value: 65.0, sum : 62.0
# element1 : 15.0,element2 : 40.0, test value: 65.0, sum : 55.0
# element1 : 15.0,element2 : 62.0, test value: 65.0, sum : 77.0
# here2
# 0
# element1 : 25.0,element2: 25.0, No sum
# element1 : 25.0,element2 : 47.0, test value: 95.0, sum : 72.0
# element1 : 25.0,element2 : 40.0, test value: 95.0, sum : 65.0
# element1 : 25.0,element2 : 62.0, test value: 95.0, sum : 87.0
# element1 : 25.0,element2 : 55.0, test value: 95.0, sum : 80.0
# here2
# 0
# element1 : 47.0,element2: 47.0, No sum
# element1 : 47.0,element2 : 40.0, test value: 102.0, sum : 87.0
# element1 : 47.0,element2 : 62.0, test value: 102.0, sum : 109.0
# element1 : 47.0,element2 : 55.0, test value: 102.0, sum : 102.0
# element1 : 47.0,element2 : 65.0, test value: 102.0, sum : 112.0
# here2
# 0
# element1 : 40.0,element2: 40.0, No sum
# element1 : 40.0,element2 : 62.0, test value: 117.0, sum : 102.0
# element1 : 40.0,element2 : 55.0, test value: 117.0, sum : 95.0
# element1 : 40.0,element2 : 65.0, test value: 117.0, sum : 105.0
# element1 : 40.0,element2 : 95.0, test value: 117.0, sum : 135.0
# here2
# 0
# element1 : 62.0,element2: 62.0, No sum
# element1 : 62.0,element2 : 55.0, test value: 150.0, sum : 117.0
# element1 : 62.0,element2 : 65.0, test value: 150.0, sum : 127.0
# element1 : 62.0,element2 : 95.0, test value: 150.0, sum : 157.0
# element1 : 62.0,element2 : 102.0, test value: 150.0, sum : 164.0
# here2
# 0
# element1 : 55.0,element2: 55.0, No sum
# element1 : 55.0,element2 : 65.0, test value: 182.0, sum : 120.0
# element1 : 55.0,element2 : 95.0, test value: 182.0, sum : 150.0
# element1 : 55.0,element2 : 102.0, test value: 182.0, sum : 157.0
# element1 : 55.0,element2 : 117.0, test value: 182.0, sum : 172.0
# here2
# 0
# element1 : 65.0,element2: 65.0, No sum
# element1 : 65.0,element2 : 95.0, test value: 127.0, sum : 160.0
# element1 : 65.0,element2 : 102.0, test value: 127.0, sum : 167.0
# element1 : 65.0,element2 : 117.0, test value: 127.0, sum : 182.0
# element1 : 65.0,element2 : 150.0, test value: 127.0, sum : 215.0
# here2
# 0
# element1 : 95.0,element2: 95.0, No sum
# element1 : 95.0,element2 : 102.0, test value: 219.0, sum : 197.0
# element1 : 95.0,element2 : 117.0, test value: 219.0, sum : 212.0
# element1 : 95.0,element2 : 150.0, test value: 219.0, sum : 245.0
# element1 : 95.0,element2 : 182.0, test value: 219.0, sum : 277.0
# here2
# 0
# element1 : 102.0,element2: 102.0, No sum
# element1 : 102.0,element2 : 117.0, test value: 299.0, sum : 219.0
# element1 : 102.0,element2 : 150.0, test value: 299.0, sum : 252.0
# element1 : 102.0,element2 : 182.0, test value: 299.0, sum : 284.0
# element1 : 102.0,element2 : 127.0, test value: 299.0, sum : 229.0
# here2
# 0
# element1 : 117.0,element2: 117.0, No sum
# element1 : 117.0,element2 : 150.0, test value: 277.0, sum : 267.0
# element1 : 117.0,element2 : 182.0, test value: 277.0, sum : 299.0
# element1 : 117.0,element2 : 127.0, test value: 277.0, sum : 244.0
# element1 : 117.0,element2 : 219.0, test value: 277.0, sum : 336.0
# here2
# 0
# element1 : 150.0,element2: 150.0, No sum
# element1 : 150.0,element2 : 182.0, test value: 309.0, sum : 332.0
# element1 : 150.0,element2 : 127.0, test value: 309.0, sum : 277.0
# element1 : 150.0,element2 : 219.0, test value: 309.0, sum : 369.0
# element1 : 150.0,element2 : 299.0, test value: 309.0, sum : 449.0
# here2
# 0
# element1 : 182.0,element2: 182.0, No sum
# element1 : 182.0,element2 : 127.0, test value: 576.0, sum : 309.0
# element1 : 182.0,element2 : 219.0, test value: 576.0, sum : 401.0
# element1 : 182.0,element2 : 299.0, test value: 576.0, sum : 481.0
# element1 : 182.0,element2 : 277.0, test value: 576.0, sum : 459.0
# here1
# 576.0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-89-9d6f47103c22> in <module>
#      52     preamble = my_data[i[0]:i[0]+preamble_count]
#      53 #     print(preamble)
# ---> 54     test_val = my_data[i[0]+preamble_count+1]
#      55 #     print("new loop")
#      56     flag=0
#
# IndexError: index 20 is out of bounds for axis 0 with size 20
