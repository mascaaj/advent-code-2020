# %%
import numpy as np
import pandas as pd
import re
import math

# %%
filename = "../data/data.txt"
df = pd.read_csv(filename, sep="\n", header=None)
df = df[0].str.split(',',expand=True)
df.columns = ["original", "content2", "content3", "content4"]

df[["original","content1"]] = df['original'].str.split("contain",expand=True)
# print(df)
cols = df.shape[1]
rows = df.shape[0]
df["original_num"]=""
df["original_color"]=""
df["content1_num"]=""
df["content1_color"]=""
df["content2_num"]=""
df["content2_color"]=""
df["content3_num"]=""
df["content3_color"]=""
df["content4_num"]=""
df["content4_color"]=""
# print(df.head())

def split_string_col(df,col_name,row):
    a = df[col_name][row]
    a2 = isinstance(a, float)
    if a2==False and a is not None:
        b = a
        c = b.split(" ")
        if not c[0]=="no" :
            df[col_name+"_color"][row] = c[2]+c[3]
            df[col_name+"_num"][row] = c[1]
        else:
            df[col_name+"_color"][row] = "no"
            df[col_name+"_num"][row] = 0
    else:
        df[col_name][row] = "no"
        df[col_name+"_color"][row] = "no"
        df[col_name+"_num"][row] = 0
    return(df)

def split_string_col2(df,col_name,row):
    a = df[col_name][row]
    a2 = isinstance(a, float)
    if a2==False and a is not None:
        b = a
        c = b.split(" ")
        if not c[0]=="no" :
            df[col_name+"_color"][row] = c[0]+c[1]
            df[col_name+"_num"][row] = c[1]
        else:
            df[col_name+"_color"][row] = "no"
            df[col_name+"_num"][row] = 0
    else:
        df[col_name][row] = "no"
        df[col_name+"_color"][row] = "no"
        df[col_name+"_num"][row] = 0
    return(df)

for i in range(1,cols):
    for row in range(0,rows):
        col_name="content"+str(i)
        df_c1 = split_string_col(df,col_name,row)

for row in range(0,rows):
    col_name="original"
    df_final = split_string_col2(df,col_name,row)
print(df_final)
# Out:
#                   original              content2                content3  \
# 0    mirrored silver bags                     no                      no
# 1          clear tan bags       1 pale black bag      5 muted lime bags.
# 2        dim crimson bags      2 clear cyan bags     2 striped lime bags
# 3     mirrored beige bags       1 pale aqua bag.                      no
# 4        pale maroon bags                     no                      no
# ..                     ...                   ...                     ...
# 589  striped crimson bags       5 dim white bags   3 clear fuchsia bags.
# 590    bright orange bags    5 posh tomato bags.                      no
# 591  bright lavender bags     4 posh salmon bags         4 dim tan bags.
# 592       plaid gold bags      5 dim orange bags     2 faded tomato bags
# 593     light violet bags                     no                      no
#
#                     content4                content1 original_num  \
# 0                         no       4 wavy gray bags.       silver
# 1                         no    5 bright purple bags          tan
# 2     5 vibrant violet bags.   5 vibrant salmon bags      crimson
# 3                         no        4 pale gold bags        beige
# 4                         no   2 dotted orange bags.       maroon
# ..                       ...                     ...          ...
# 589                       no       1 pale orange bag      crimson
# 590                       no      5 faded olive bags       orange
# 591                       no      4 posh yellow bags     lavender
# 592     4 faded purple bags.     5 wavy magenta bags         gold
# 593                       no       1 plaid aqua bag.       violet
#
#      original_color content1_num content1_color content2_num content2_color  \
# 0    mirroredsilver            4       wavygray            0             no
# 1          cleartan            5   brightpurple            1      paleblack
# 2        dimcrimson            5  vibrantsalmon            2      clearcyan
# 3     mirroredbeige            4       palegold            1       paleaqua
# 4        palemaroon            2   dottedorange            0             no
# ..              ...          ...            ...          ...            ...
# 589  stripedcrimson            1     paleorange            5       dimwhite
# 590    brightorange            5     fadedolive            5     poshtomato
# 591  brightlavender            4     poshyellow            4     poshsalmon
# 592       plaidgold            5    wavymagenta            5      dimorange
# 593     lightviolet            1      plaidaqua            0             no
#
#     content3_num content3_color content4_num content4_color
# 0              0             no            0             no
# 1              5      mutedlime            0             no
# 2              2    stripedlime            5  vibrantviolet
# 3              0             no            0             no
# 4              0             no            0             no
# ..           ...            ...          ...            ...
# 589            3   clearfuchsia            0             no
# 590            0             no            0             no
# 591            4         dimtan            0             no
# 592            2    fadedtomato            4    fadedpurple
# 593            0             no            0             no
#
# [594 rows x 15 columns]

# %%
rows2 = df_final.shape[0]
vals = ["shinygold"] 
test_vals = []
for row in range(0,rows2):
    for i in range(0,len(vals)):
        if df_final["original_color"][row] == vals[0]:
            test_vals.append(df_final["original_color"][row])
            if not df_final["content1_color"][row]=="no":
                test_vals.append(df_final["content1_color"][row])
            elif not df_final["content2_color"][row]=="no":
                test_vals.append(df_final["content2_color"][row])
            elif not df_final["content3_color"][row]=="no":
                test_vals.append(df_final["content3_color"][row])
            elif not df_final["content4_color"][row]=="no":
                test_vals.append(df_final["content4_color"][row])
test_vals = np.unique(test_vals)
test_vals = test_vals.tolist()
new_total = len(test_vals)
print(new_total)


old_total = 0
new_total = 1
while old_total !=new_total:
    old_total =  new_total
    for row in range(0,rows2):
        for i in range(0,len(test_vals)):
            if df_final["original_color"][row] == test_vals[i]:
                test_vals.append(df_final["original_color"][row])
                if not df_final["content1_color"][row]=="otherbags."and not df_final["content1_color"][row]=="otherbags.":
                    test_vals.append(df_final["content1_color"][row])
                    if not df_final["content2_color"][row]=="otherbags." and not df_final["content2_color"][row]=="no":
                        test_vals.append(df_final["content2_color"][row])
                        if not df_final["content3_color"][row]=="otherbags." and not df_final["content3_color"][row]=="no":
                            test_vals.append(df_final["content3_color"][row])
                            if not df_final["content4_color"][row]=="otherbags." and not df_final["content4_color"][row]=="no":
                                test_vals.append(df_final["content4_color"][row])
                
    test_vals = np.unique(test_vals)
    test_vals = test_vals.tolist()
    new_total = len(test_vals)
    print(test_vals)
    print(new_total)
    
    
for row in range(0,rows2):
    for i in range(0,len(test_vals)):
        if df_final["original_color"][row] == test_vals[i]:
            print(df.iloc[row,:])
            

# print(df_final["content1_col"][340])
# Out:
# 2
# ['clearchartreuse', 'dullindigo', 'paleplum', 'shinygold']
# 4
# ['clearchartreuse', 'dullindigo', 'mutedmaroon', 'mutedplum', 'paleplum', 'shinybeige', 'shinygold', 'wavyindigo']
# 8
# ['brightturquoise', 'clearchartreuse', 'clearyellow', 'darkblack', 'dottedorange', 'dullindigo', 'mutedmaroon', 'mutedplum', 'mutedpurple', 'palelavender', 'paleplum', 'poshsalmon', 'shinybeige', 'shinygold', 'shinylavender', 'shinypurple', 'stripedmagenta', 'wavyindigo']
# 18
# ['brightturquoise', 'clearchartreuse', 'clearyellow', 'darkblack', 'dottedorange', 'dullindigo', 'mutedgold', 'mutedmaroon', 'mutedplum', 'mutedpurple', 'palelavender', 'paleplum', 'paletan', 'poshsalmon', 'shinybeige', 'shinygold', 'shinylavender', 'shinypurple', 'stripedmagenta', 'vibrantmagenta', 'wavyindigo']
# 21
# ['brightturquoise', 'clearchartreuse', 'clearyellow', 'darkblack', 'dottedorange', 'dullindigo', 'mutedgold', 'mutedmaroon', 'mutedplum', 'mutedpurple', 'palelavender', 'paleplum', 'paletan', 'poshsalmon', 'shinybeige', 'shinygold', 'shinylavender', 'shinypurple', 'stripedmagenta', 'vibrantmagenta', 'wavyindigo']
# 21
# original             shiny lavender bags
# content2           1 bright turquoise bag
# content3               2 shiny beige bags
# content4                 4 pale tan bags.
# content1           5 vibrant magenta bags
# original_num                     lavender
# original_color              shinylavender
# content1_num                            5
# content1_color             vibrantmagenta
# content2_num                            1
# content2_color            brightturquoise
# content3_num                            2
# content3_color                 shinybeige
# content4_num                            4
# content4_color                    paletan
# Name: 28, dtype: object
# original                 shiny purple bags
# content2             3 vibrant magenta bags
# content3                    3 pale tan bags
# content4           4 bright turquoise bags.
# content1                  4 dark black bags
# original_num                         purple
# original_color                  shinypurple
# content1_num                              4
# content1_color                    darkblack
# content2_num                              3
# content2_color               vibrantmagenta
# content3_num                              3
# content3_color                      paletan
# content4_num                              4
# content4_color              brightturquoise
# Name: 48, dtype: object
# original               wavy indigo bags
# content2               2 dark black bags
# content3           2 dotted orange bags.
# content4                              no
# content1             5 muted purple bags
# original_num                      indigo
# original_color                wavyindigo
# content1_num                           5
# content1_color               mutedpurple
# content2_num                           2
# content2_color                 darkblack
# content3_num                           2
# content3_color              dottedorange
# content4_num                           0
# content4_color                        no
# Name: 93, dtype: object
# original                  shiny beige bags
# content2                 5 posh salmon bags
# content3              1 striped magenta bag
# content4           3 bright turquoise bags.
# content1                5 clear yellow bags
# original_num                          beige
# original_color                   shinybeige
# content1_num                              5
# content1_color                  clearyellow
# content2_num                              5
# content2_color                   poshsalmon
# content3_num                              1
# content3_color               stripedmagenta
# content4_num                              3
# content4_color              brightturquoise
# Name: 114, dtype: object
# original          bright turquoise bags
# content2                              no
# content3                              no
# content4                              no
# content1                  no other bags.
# original_num                   turquoise
# original_color           brightturquoise
# content1_num                          no
# content1_color                otherbags.
# content2_num                           0
# content2_color                        no
# content3_num                           0
# content3_color                        no
# content4_num                           0
# content4_color                        no
# Name: 162, dtype: object
# original               pale tan bags
# content2                           no
# content3                           no
# content4                           no
# content1           2 muted gold bags.
# original_num                      tan
# original_color                paletan
# content1_num                        2
# content1_color              mutedgold
# content2_num                        0
# content2_color                     no
# content3_num                        0
# content3_color                     no
# content4_num                        0
# content4_color                     no
# Name: 177, dtype: object
# original              pale plum bags
# content2           5 wavy indigo bags
# content3           3 muted plum bags.
# content4                           no
# content1            1 shiny beige bag
# original_num                     plum
# original_color               paleplum
# content1_num                        1
# content1_color             shinybeige
# content2_num                        5
# content2_color             wavyindigo
# content3_num                        3
# content3_color              mutedplum
# content4_num                        0
# content4_color                     no
# Name: 183, dtype: object
# original                   dark black bags
# content2           2 bright turquoise bags.
# content3                                 no
# content4                                 no
# content1                2 muted maroon bags
# original_num                          black
# original_color                    darkblack
# content1_num                              2
# content1_color                  mutedmaroon
# content2_num                              2
# content2_color              brightturquoise
# content3_num                              0
# content3_color                           no
# content4_num                              0
# content4_color                           no
# Name: 204, dtype: object
# original             striped magenta bags
# content2                5 dull indigo bags
# content3              3 clear yellow bags.
# content4                                no
# content1           2 bright turquoise bags
# original_num                       magenta
# original_color              stripedmagenta
# content1_num                             2
# content1_color             brightturquoise
# content2_num                             5
# content2_color                  dullindigo
# content3_num                             3
# content3_color                 clearyellow
# content4_num                             0
# content4_color                          no
# Name: 227, dtype: object
# original             posh salmon bags
# content2                            no
# content3                            no
# content4                            no
# content1           4 dull indigo bags.
# original_num                    salmon
# original_color              poshsalmon
# content1_num                         4
# content1_color              dullindigo
# content2_num                         0
# content2_color                      no
# content3_num                         0
# content3_color                      no
# content4_num                         0
# content4_color                      no
# Name: 238, dtype: object
# original          dull indigo bags
# content2                         no
# content3                         no
# content4                         no
# content1             no other bags.
# original_num                 indigo
# original_color           dullindigo
# content1_num                     no
# content1_color           otherbags.
# content2_num                      0
# content2_color                   no
# content3_num                      0
# content3_color                   no
# content4_num                      0
# content4_color                   no
# Name: 255, dtype: object
# original          pale lavender bags
# content2                           no
# content3                           no
# content4                           no
# content1               no other bags.
# original_num                 lavender
# original_color           palelavender
# content1_num                       no
# content1_color             otherbags.
# content2_num                        0
# content2_color                     no
# content3_num                        0
# content3_color                     no
# content4_num                        0
# content4_color                     no
# Name: 311, dtype: object
# original          clear chartreuse bags
# content2             4 dull indigo bags.
# content3                              no
# content4                              no
# content1                2 pale plum bags
# original_num                  chartreuse
# original_color           clearchartreuse
# content1_num                           2
# content1_color                  paleplum
# content2_num                           4
# content2_color                dullindigo
# content3_num                           0
# content3_color                        no
# content4_num                           0
# content4_color                        no
# Name: 321, dtype: object
# original          muted gold bags
# content2                        no
# content3                        no
# content4                        no
# content1            no other bags.
# original_num                  gold
# original_color           mutedgold
# content1_num                    no
# content1_color          otherbags.
# content2_num                     0
# content2_color                  no
# content3_num                     0
# content3_color                  no
# content4_num                     0
# content4_color                  no
# Name: 331, dtype: object
# original                   shiny gold bags
# content2                                 no
# content3                                 no
# content4                                 no
# content1           2 clear chartreuse bags.
# original_num                           gold
# original_color                    shinygold
# content1_num                              2
# content1_color              clearchartreuse
# content2_num                              0
# content2_color                           no
# content3_num                              0
# content3_color                           no
# content4_num                              0
# content4_color                           no
# Name: 340, dtype: object
# original          clear yellow bags
# content2                          no
# content3                          no
# content4                          no
# content1              no other bags.
# original_num                  yellow
# original_color           clearyellow
# content1_num                      no
# content1_color            otherbags.
# content2_num                       0
# content2_color                    no
# content3_num                       0
# content3_color                    no
# content4_num                       0
# content4_color                    no
# Name: 416, dtype: object
# original          vibrant magenta bags
# content2                             no
# content3                             no
# content4                             no
# content1                 no other bags.
# original_num                    magenta
# original_color           vibrantmagenta
# content1_num                         no
# content1_color               otherbags.
# content2_num                          0
# content2_color                       no
# content3_num                          0
# content3_color                       no
# content4_num                          0
# content4_color                       no
# Name: 472, dtype: object
# original            dotted orange bags
# content2                             no
# content3                             no
# content4                             no
# content1           3 shiny purple bags.
# original_num                     orange
# original_color             dottedorange
# content1_num                          3
# content1_color              shinypurple
# content2_num                          0
# content2_color                       no
# content3_num                          0
# content3_color                       no
# content4_num                          0
# content4_color                       no
# Name: 477, dtype: object
# original          muted maroon bags
# content2                          no
# content3                          no
# content4                          no
# content1              no other bags.
# original_num                  maroon
# original_color           mutedmaroon
# content1_num                      no
# content1_color            otherbags.
# content2_num                       0
# content2_color                    no
# content3_num                       0
# content3_color                    no
# content4_num                       0
# content4_color                    no
# Name: 522, dtype: object
# original              muted purple bags
# content2              4 shiny beige bags
# content3           2 pale lavender bags.
# content4                              no
# content1           2 shiny lavender bags
# original_num                      purple
# original_color               mutedpurple
# content1_num                           2
# content1_color             shinylavender
# content2_num                           4
# content2_color                shinybeige
# content3_num                           2
# content3_color              palelavender
# content4_num                           0
# content4_color                        no
# Name: 527, dtype: object
# original              muted plum bags
# content2                            no
# content3                            no
# content4                            no
# content1           1 muted maroon bag.
# original_num                      plum
# original_color               mutedplum
# content1_num                         1
# content1_color             mutedmaroon
# content2_num                         0
# content2_color                      no
# content3_num                         0
# content3_color                      no
# content4_num                         0
# content4_color                      no
# Name: 576, dtype: object

# %%
# for row in range(0,rows2):
#         if df_final["content1_color"][row] == vals[0]: 
#             df_final["original_num"][row] = 1
#             test_vals.append(df_final["original_color"][row])
#         elif df_final["content2_color"][row] == vals[0]:
#             df_final["original_num"][row] = 1
#             test_vals.append(df_final["original_color"][row])
#         elif df_final["content3_color"][row] == vals[0]:
#             df_final["original_num"][row] = 1
#             test_vals.append(df_final["original_color"][row])
#         elif df_final["content4_color"][row] == vals[0]:
#             df_final["original_num"][row] = 1
#             test_vals.append(df_final["original_color"][row])
#         else:
#             df_final["original_num"][row] = 0 


# test_vals = np.unique(test_vals)
# test_vals = test_vals.tolist()
# print(test_vals)
# print(len(test_vals))
# old_total = 0
# new_total = 1
# while old_total!=new_total:
#     old_total =  new_total
#     for row in range(0,rows2):
#         for i in range(0,len(test_vals)):
#             if df_final["content1_color"][row] == test_vals[i]: 
#                 df_final["original_num"][row] = 1
#                 test_vals.append(df_final["original_color"][row])
#             elif df_final["content2_color"][row] == test_vals[i]:
#                 df_final["original_num"][row] = 1
#                 test_vals.append(df_final["original_color"][row])
#             elif df_final["content3_color"][row] == test_vals[i]:
#                 df_final["original_num"][row] = 1
#                 test_vals.append(df_final["original_color"][row])
#             elif df_final["content4_color"][row] == test_vals[i]:
#                 df_final["original_num"][row] = 1
#                 test_vals.append(df_final["original_color"][row])
#     test_vals = np.unique(test_vals)
#     test_vals = test_vals.tolist()
#     print(test_vals)
#     new_total = len(test_vals)
#     print(new_total)

# print(df_final["original_num"])
# print(sum(df_final["original_num"]))
