# %%
import numpy as np
import pandas as pd
import re
import math

# %%
filename = "../data/data.txt"
df = pd.read_csv(filename, sep="\n", header=None)
df = df[0].str.split(',',expand=True)
df.columns = ["original", "content2", "content3", "content4"]

df[["original","content1"]] = df['original'].str.split("contain",expand=True)
# print(df)
cols = df.shape[1]
rows = df.shape[0]
df["original_num"]=""
df["original_color"]=""
df["content1_num"]=""
df["content1_color"]=""
df["content2_num"]=""
df["content2_color"]=""
df["content3_num"]=""
df["content3_color"]=""
df["content4_num"]=""
df["content4_color"]=""
# print(df.head())

def split_string_col(df,col_name,row):
    a = df[col_name][row]
    a2 = isinstance(a, float)
    if a2==False and a is not None:
        b = a
        c = b.split(" ")
        if not c[0]=="no" :
            df[col_name+"_color"][row] = c[2]+c[3]
            df[col_name+"_num"][row] = c[1]
        else:
            df[col_name+"_color"][row] = "no"
            df[col_name+"_num"][row] = "no"
    else:
        df[col_name][row] = "no"
        df[col_name+"_color"][row] = "no"
        df[col_name+"_num"][row] = "no"
    return(df)

def split_string_col2(df,col_name,row):
    a = df[col_name][row]
    a2 = isinstance(a, float)
    if a2==False and a is not None:
        b = a
        c = b.split(" ")
        if not c[0]=="no" :
            df[col_name+"_color"][row] = c[0]+c[1]
            df[col_name+"_num"][row] = c[1]
        else:
            df[col_name+"_color"][row] = "no"
            df[col_name+"_num"][row] = "no"
    else:
        df[col_name][row] = "no"
        df[col_name+"_color"][row] = "no"
        df[col_name+"_num"][row] = "no"
    return(df)

for i in range(1,cols):
    for row in range(0,rows):
        col_name="content"+str(i)
        df_c1 = split_string_col(df,col_name,row)

for row in range(0,rows):
    col_name="original"
    df_final = split_string_col2(df,col_name,row)
print(df)
# Out:
#                   original              content2                content3  \
# 0    mirrored silver bags                     no                      no
# 1          clear tan bags       1 pale black bag      5 muted lime bags.
# 2        dim crimson bags      2 clear cyan bags     2 striped lime bags
# 3     mirrored beige bags       1 pale aqua bag.                      no
# 4        pale maroon bags                     no                      no
# ..                     ...                   ...                     ...
# 589  striped crimson bags       5 dim white bags   3 clear fuchsia bags.
# 590    bright orange bags    5 posh tomato bags.                      no
# 591  bright lavender bags     4 posh salmon bags         4 dim tan bags.
# 592       plaid gold bags      5 dim orange bags     2 faded tomato bags
# 593     light violet bags                     no                      no
#
#                     content4                content1 original_num  \
# 0                         no       4 wavy gray bags.       silver
# 1                         no    5 bright purple bags          tan
# 2     5 vibrant violet bags.   5 vibrant salmon bags      crimson
# 3                         no        4 pale gold bags        beige
# 4                         no   2 dotted orange bags.       maroon
# ..                       ...                     ...          ...
# 589                       no       1 pale orange bag      crimson
# 590                       no      5 faded olive bags       orange
# 591                       no      4 posh yellow bags     lavender
# 592     4 faded purple bags.     5 wavy magenta bags         gold
# 593                       no       1 plaid aqua bag.       violet
#
#      original_color content1_num content1_color content2_num content2_color  \
# 0    mirroredsilver            4       wavygray           no             no
# 1          cleartan            5   brightpurple            1      paleblack
# 2        dimcrimson            5  vibrantsalmon            2      clearcyan
# 3     mirroredbeige            4       palegold            1       paleaqua
# 4        palemaroon            2   dottedorange           no             no
# ..              ...          ...            ...          ...            ...
# 589  stripedcrimson            1     paleorange            5       dimwhite
# 590    brightorange            5     fadedolive            5     poshtomato
# 591  brightlavender            4     poshyellow            4     poshsalmon
# 592       plaidgold            5    wavymagenta            5      dimorange
# 593     lightviolet            1      plaidaqua           no             no
#
#     content3_num content3_color content4_num content4_color
# 0             no             no           no             no
# 1              5      mutedlime           no             no
# 2              2    stripedlime            5  vibrantviolet
# 3             no             no           no             no
# 4             no             no           no             no
# ..           ...            ...          ...            ...
# 589            3   clearfuchsia           no             no
# 590           no             no           no             no
# 591            4         dimtan           no             no
# 592            2    fadedtomato            4    fadedpurple
# 593           no             no           no             no
#
# [594 rows x 15 columns]

# %%
rows2 = df_final.shape[0]
vals = ["shinygold"] 
test_vals = []
for row in range(0,rows2):
        if df_final["content1_color"][row] == vals[0]: 
            df_final["original_num"][row] = 1
            test_vals.append(df_final["original_color"][row])
        elif df_final["content2_color"][row] == vals[0]:
            df_final["original_num"][row] = 1
            test_vals.append(df_final["original_color"][row])
        elif df_final["content3_color"][row] == vals[0]:
            df_final["original_num"][row] = 1
            test_vals.append(df_final["original_color"][row])
        elif df_final["content4_color"][row] == vals[0]:
            df_final["original_num"][row] = 1
            test_vals.append(df_final["original_color"][row])
        else:
            df_final["original_num"][row] = 0 


test_vals = np.unique(test_vals)
test_vals = test_vals.tolist()
print(test_vals)
print(len(test_vals))
old_total = 0
new_total = 1
while old_total!=new_total:
    old_total =  new_total
    for row in range(0,rows2):
        for i in range(0,len(test_vals)):
            if df_final["content1_color"][row] == test_vals[i]: 
                df_final["original_num"][row] = 1
                test_vals.append(df_final["original_color"][row])
            elif df_final["content2_color"][row] == test_vals[i]:
                df_final["original_num"][row] = 1
                test_vals.append(df_final["original_color"][row])
            elif df_final["content3_color"][row] == test_vals[i]:
                df_final["original_num"][row] = 1
                test_vals.append(df_final["original_color"][row])
            elif df_final["content4_color"][row] == test_vals[i]:
                df_final["original_num"][row] = 1
                test_vals.append(df_final["original_color"][row])
    test_vals = np.unique(test_vals)
    test_vals = test_vals.tolist()
    print(test_vals)
    new_total = len(test_vals)
    print(new_total)


for row in range(0,rows2):
    for i in range(0,len(test_vals)):
        if df_final["original_color"][row] == test_vals[i]: 
            df_final["original_num"][row] = 1


print(df_final["original_num"])
print(sum(df_final["original_num"]))
# Out:
# ['clearsilver', 'darkbrown', 'dottedbrown', 'dulllavender', 'mirroredtan', 'plaidturquoise', 'shinytomato']
# 7
# ['brightgreen', 'brightred', 'brightsalmon', 'clearred', 'clearsilver', 'clearviolet', 'darkbrown', 'darkcrimson', 'darkgreen', 'darkindigo', 'dimmaroon', 'dottedbeige', 'dottedbrown', 'dottedgray', 'dottedindigo', 'dottedplum', 'dottedsilver', 'dottedteal', 'dottedtomato', 'drabbronze', 'drabbrown', 'draborange', 'dullblue', 'dullcrimson', 'dullgold', 'dulllavender', 'dullmaroon', 'dullturquoise', 'dullyellow', 'fadedfuchsia', 'fadedmagenta', 'fadedplum', 'mirroredfuchsia', 'mirroredmaroon', 'mirroredtan', 'mirroredteal', 'mutedblue', 'mutedfuchsia', 'mutedred', 'paleblue', 'palelime', 'palesalmon', 'palesilver', 'plaidblack', 'plaidbronze', 'plaidlime', 'plaidtan', 'plaidtomato', 'plaidturquoise', 'plaidviolet', 'poshbeige', 'posholive', 'poshpurple', 'poshsilver', 'shinyindigo', 'shinymagenta', 'shinymaroon', 'shinyred', 'shinysilver', 'shinytomato', 'shinyviolet', 'stripedcyan', 'stripedfuchsia', 'stripedtomato', 'vibrantaqua', 'vibrantlavender', 'vibrantviolet', 'vibrantwhite', 'wavybrown']
# 69
# ['brightaqua', 'brightblack', 'brightbrown', 'brightcrimson', 'brightgreen', 'brightmagenta', 'brightmaroon', 'brightred', 'brightsalmon', 
 'dullgold', 'dullgreen', 'dulllavender', 'dullmaroon', 'dullred', 'dulltan', 'dullturquoise', 'dullviolet', 'dullwhite', 'dullyellow', 'fadedbronze', 'fadedchartreuse', 'fadedcoral', 'fadedfuchsia', 'fadedgreen', 'fadedlavender', 'fadedmagenta', 'fadedmaroon', 'fadedplum', 'fadedsilver', 'fadedtan', 'fadedyellow', 'lightaqua', 'lightbeige', 'lightblack', 'lightcoral', 'lightcrimson', 'lightcyan', 'lightgold', 'lightgreen', 'lightindigo', 'lightorange', 'lightred', 'lightsalmon', 'lightteal', 'lighttomato', 'lightviolet', 'lightwhite', 'lightyellow', 'mirroredaqua', 'mirroredblack', 'mirroredblue', 'mirroredbronze', 'mirroredbrown', 'mirroredcoral', 'mirroredcyan', 'mirroredfuchsia', 'mirroredgold', 'mirroredindigo', 'mirroredmaroon', 'mirroredpurple', 'mirroredtan', 'mirroredteal', 'mirroredturquoise', 'mutedblack', 'mutedblue', 'mutedchartreuse', 'mutedcoral', 'mutedfuchsia', 'mutedindigo', 'mutedmagenta', 'mutedred', 'mutedsalmon', 'mutedtomato', 'mutedwhite', 'mutedyellow', 'paleblue', 'palebronze', 'palefuchsia', 'palelime', 'palesalmon', 'palesilver', 'paleyellow', 'plaidaqua', 'plaidblack', 'plaidbronze', 'plaidchartreuse', 'plaidcoral', 'plaidcyan', 'plaidfuchsia', 'plaidgold', 'plaidlavender', 'plaidlime', 'plaidolive', 'plaidorange', 'plaidplum', 'plaidred', 'plaidtan', 'plaidteal', 'plaidtomato', 'plaidturquoise', 'plaidviolet', 'poshbeige', 'poshblue', 'poshbrown', 'poshgold', 'poshmaroon', 'posholive', 'poshpurple', 'poshred', 'poshsilver', 'poshteal', 'poshturquoise', 'shinyblack', 'shinychartreuse', 'shinycoral', 'shinycyan', 'shinyindigo', 'shinymagenta', 'shinymaroon', 'shinyolive', 'shinyred', 'shinysilver', 'shinyteal', 'shinytomato', 'shinyturquoise', 'shinyviolet', 'stripedbeige', 'stripedcyan', 'stripedfuchsia', 'stripedmaroon', 'stripedsilver', 'stripedtomato', 'stripedturquoise', 'vibrantaqua', 'vibrantblue', 'vibrantchartreuse', 'vibrantcrimson', 'vibrantfuchsia', 'vibrantgold', 'vibrantgreen', 'vibrantindigo', 'vibrantlavender', 'vibrantlime', 'vibrantolive', 'vibrantred', 'vibrantsalmon', 'vibrantsilver', 'vibrantturquoise', 'vibrantviolet', 'vibrantwhite', 'wavybrown', 'wavycyan', 'wavygreen', 'wavylavender', 'wavymagenta', 'wavyolive', 'wavyplum', 'wavypurple', 'wavyred', 'wavysalmon', 'wavytan', 'wavywhite', 'wavyyellow']
# 253
# ['brightaqua', 'brightblack', 'brightbrown', 'brightcoral', 'brightcrimson', 'brightgray', 'brightgreen', 'brightmagenta', 'brightmaroon', 'brightred', 'brightsalmon', 'brighttomato', 'brightwhite', 'clearbeige', 'clearbronze', 'clearbrown', 'clearcoral', 'cleargold', 'clearindigo', 'clearlime', 'clearmaroon', 'clearplum', 'clearred', 'clearsilver', 'clearteal', 'cleartomato', 'clearviolet', 'clearwhite', 'darkaqua', 'darkblue', 'darkbrown', 'darkcrimson', 'darkgreen', 'darkindigo', 'darklavender', 'darklime', 'darkmagenta', 'darkolive', 'darkred', 'darksilver', 'darkteal', 'darktomato', 'darkviolet', 'dimblack', 'dimblue', 'dimbronze', 'dimcoral', 'dimcrimson', 'dimcyan', 'dimfuchsia', 'dimindigo', 'dimmagenta', 'dimmaroon', 'dimplum', 'dimsalmon', 'dimteal', 'dimtomato', 'dimturquoise', 'dottedaqua', 'dottedbeige', 'dottedblack', 'dottedbrown', 'dottedchartreuse', 'dottedgold', 'dottedgray', 'dottedgreen', 'dottedindigo', 'dottedlime', 'dottedolive', 'dottedplum', 'dottedpurple', 'dottedred', 'dottedsilver', 'dottedteal', 'dottedtomato', 'dottedviolet', 'dottedwhite', 'drabbeige', 'drabblue', 'drabbronze', 'drabbrown', 'drabcrimson', 'drabcyan', 'drabfuchsia', 'drabgold', 'drabindigo', 'drablavender', 'draborange', 'drabplum', 'drabsilver', 'drabteal', 'drabtomato', 'drabturquoise', 'drabviolet', 'dullbeige', 'dullblack', 'dullblue', 'dullbrown', 'dullchartreuse', 'dullcrimson', 'dullfuchsia', 'dullgold', 'dullgreen', 'dulllavender', 'dullmaroon', 'dullred', 'dulltan', 'dullturquoise', 'dullviolet', 'dullwhite', 'dullyellow', 'fadedbronze', 'fadedchartreuse', 'fadedcoral', 'fadedfuchsia', 'fadedgreen', 'fadedlavender', 'fadedmagenta', 'fadedmaroon', 'fadedplum', 'fadedsilver', 'fadedtan', 'fadedyellow', 'lightaqua', 'lightbeige', 'lightblack', 'lightbronze', 'lightcoral', 'lightcrimson', 'lightcyan', 'lightgold', 'lightgreen', 'lightindigo', 'lightorange', 'lightred', 'lightsalmon', 'lightteal', 'lighttomato', 'lightviolet', 'lightwhite', 'lightyellow', 'mirroredaqua', 'mirroredblack', 'mirroredblue', 'mirroredbronze', 'mirroredbrown', 'mirroredcoral', 'mirroredcyan', 'mirroredfuchsia', 'mirroredgold', 'mirroredindigo', 'mirroredmaroon', 'mirroredpurple', 'mirroredtan', 'mirroredteal', 'mirroredturquoise', 'mutedblack', 'mutedblue', 'mutedchartreuse', 'mutedcoral', 'mutedfuchsia', 'mutedindigo', 'mutedmagenta', 'mutedred', 'mutedsalmon', 'mutedtan', 'mutedtomato', 'mutedwhite', 'mutedyellow', 'paleblue', 'palebronze', 'palecrimson', 'palefuchsia', 'palelime', 'palesalmon', 'palesilver', 'paleyellow', 'plaidaqua', 'plaidblack', 'plaidbronze', 'plaidchartreuse', 'plaidcoral', 'plaidcyan', 'plaidfuchsia', 'plaidgold', 'plaidlavender', 'plaidlime', 'plaidolive', 'plaidorange', 'plaidplum', 'plaidred', 'plaidtan', 'plaidteal', 'plaidtomato', 'plaidturquoise', 'plaidviolet', 'poshbeige', 'poshblue', 'poshbrown', 'poshgold', 'poshmaroon', 'posholive', 'poshpurple', 'poshred', 'poshsilver', 'poshteal', 'poshturquoise', 'shinyblack', 'shinychartreuse', 'shinycoral', 'shinycyan', 'shinyindigo', 'shinymagenta', 'shinymaroon', 'shinyolive', 'shinyred', 'shinysilver', 'shinyteal', 'shinytomato', 'shinyturquoise', 'shinyviolet', 'stripedbeige', 'stripedcyan', 'stripedfuchsia', 'stripedmaroon', 'stripedsilver', 'stripedtomato', 'stripedturquoise', 'vibrantaqua', 'vibrantblue', 'vibrantchartreuse', 'vibrantcrimson', 'vibrantfuchsia', 'vibrantgold', 'vibrantgreen', 'vibrantindigo', 'vibrantlavender', 'vibrantlime', 'vibrantolive', 'vibrantred', 'vibrantsalmon', 'vibrantsilver', 'vibrantturquoise', 'vibrantviolet', 'vibrantwhite', 'wavybrown', 'wavycyan', 'wavygreen', 'wavylavender', 'wavymagenta', 'wavyolive', 'wavyplum', 'wavypurple', 'wavyred', 'wavysalmon', 'wavytan', 'wavywhite', 'wavyyellow']
# 258
# ['brightaqua', 'brightblack', 'brightbrown', 'brightcoral', 'brightcrimson', 'brightgray', 'brightgreen', 'brightmagenta', 'brightmaroon', 'brightred', 'brightsalmon', 'brighttomato', 'brightwhite', 'clearbeige', 'clearbronze', 'clearbrown', 'clearcoral', 'cleargold', 'clearindigo', 'clearlime', 'clearmaroon', 'clearplum', 'clearred', 'clearsilver', 'clearteal', 'cleartomato', 'clearviolet', 'clearwhite', 'darkaqua', 'darkblue', 'darkbrown', 'darkcrimson', 'darkgreen', 'darkindigo', 'darklavender', 'darklime', 'darkmagenta', 'darkolive', 'darkred', 'darksilver', 'darkteal', 'darktomato', 'darkviolet', 'dimblack', 'dimblue', 'dimbronze', 'dimcoral', 'dimcrimson', 'dimcyan', 'dimfuchsia', 'dimindigo', 'dimmagenta', 'dimmaroon', 'dimplum', 'dimsalmon', 'dimteal', 'dimtomato', 'dimturquoise', 'dottedaqua', 'dottedbeige', 'dottedblack', 'dottedbrown', 'dottedchartreuse', 'dottedgold', 'dottedgray', 'dottedgreen', 'dottedindigo', 'dottedlime', 'dottedolive', 'dottedplum', 'dottedpurple', 'dottedred', 'dottedsilver', 'dottedteal', 'dottedtomato', 'dottedviolet', 'dottedwhite', 'drabbeige', 'drabblue', 'drabbronze', 'drabbrown', 'drabcrimson', 'drabcyan', 'drabfuchsia', 'drabgold', 'drabindigo', 'drablavender', 'draborange', 'drabplum', 'drabsilver', 'drabteal', 'drabtomato', 'drabturquoise', 'drabviolet', 'dullbeige', 'dullblack', 'dullblue', 'dullbrown', 'dullchartreuse', 'dullcrimson', 'dullfuchsia', 'dullgold', 'dullgreen', 'dulllavender', 'dullmaroon', 'dullred', 'dulltan', 'dullturquoise', 'dullviolet', 'dullwhite', 'dullyellow', 'fadedbronze', 'fadedchartreuse', 'fadedcoral', 'fadedfuchsia', 'fadedgreen', 'fadedlavender', 'fadedmagenta', 'fadedmaroon', 'fadedplum', 'fadedsilver', 'fadedtan', 'fadedyellow', 'lightaqua', 'lightbeige', 'lightblack', 'lightbronze', 'lightcoral', 'lightcrimson', 'lightcyan', 'lightgold', 'lightgreen', 'lightindigo', 'lightorange', 'lightred', 'lightsalmon', 'lightteal', 'lighttomato', 'lightviolet', 'lightwhite', 'lightyellow', 'mirroredaqua', 'mirroredblack', 'mirroredblue', 'mirroredbronze', 'mirroredbrown', 'mirroredcoral', 'mirroredcyan', 'mirroredfuchsia', 'mirroredgold', 'mirroredindigo', 'mirroredmaroon', 'mirroredpurple', 'mirroredtan', 'mirroredteal', 'mirroredturquoise', 'mutedblack', 'mutedblue', 'mutedchartreuse', 'mutedcoral', 'mutedfuchsia', 'mutedindigo', 'mutedmagenta', 'mutedred', 'mutedsalmon', 'mutedtan', 'mutedtomato', 'mutedwhite', 'mutedyellow', 'paleblue', 'palebronze', 'palecrimson', 'palefuchsia', 'palelime', 'palesalmon', 'palesilver', 'paleyellow', 'plaidaqua', 'plaidblack', 'plaidbronze', 'plaidchartreuse', 'plaidcoral', 'plaidcyan', 'plaidfuchsia', 'plaidgold', 'plaidlavender', 'plaidlime', 'plaidolive', 'plaidorange', 'plaidplum', 'plaidred', 'plaidtan', 'plaidteal', 'plaidtomato', 'plaidturquoise', 'plaidviolet', 'poshbeige', 'poshblue', 'poshbrown', 'poshgold', 'poshmaroon', 'posholive', 'poshpurple', 'poshred', 'poshsilver', 'poshteal', 'poshturquoise', 'shinyblack', 'shinychartreuse', 'shinycoral', 'shinycyan', 'shinyindigo', 'shinymagenta', 'shinymaroon', 'shinyolive', 'shinyred', 'shinysilver', 'shinyteal', 'shinytomato', 'shinyturquoise', 'shinyviolet', 'stripedbeige', 'stripedcyan', 'stripedfuchsia', 'stripedmaroon', 'stripedsilver', 'stripedtomato', 'stripedturquoise', 'vibrantaqua', 'vibrantblue', 'vibrantchartreuse', 'vibrantcrimson', 'vibrantfuchsia', 'vibrantgold', 'vibrantgreen', 'vibrantindigo', 'vibrantlavender', 'vibrantlime', 'vibrantolive', 'vibrantred', 'vibrantsalmon', 'vibrantsilver', 'vibranttan', 'vibrantturquoise', 'vibrantviolet', 'vibrantwhite', 'wavybrown', 'wavycyan', 'wavygreen', 'wavylavender', 'wavymagenta', 'wavyolive', 'wavyplum', 'wavypurple', 'wavyred', 'wavysalmon', 'wavytan', 'wavywhite', 'wavyyellow']
# 259
# ['brightaqua', 'brightblack', 'brightbrown', 'brightcoral', 'brightcrimson', 'brightgray', 'brightgreen', 'brightmagenta', 'brightmaroon', 'brightred', 'brightsalmon', 'brighttomato', 'brightwhite', 'clearbeige', 'clearbronze', 'clearbrown', 'clearcoral', 'cleargold', 'clearindigo', 'clearlime', 'clearmaroon', 'clearplum', 'clearred', 'clearsilver', 'clearteal', 'cleartomato', 'clearviolet', 'clearwhite', 'darkaqua', 'darkblue', 'darkbrown', 'darkcrimson', 'darkgreen', 'darkindigo', 'darklavender', 'darklime', 'darkmagenta', 'darkolive', 'darkred', 'darksilver', 'darkteal', 'darktomato', 'darkviolet', 'dimblack', 'dimblue', 'dimbronze', 'dimcoral', 'dimcrimson', 'dimcyan', 'dimfuchsia', 'dimindigo', 'dimmagenta', 'dimmaroon', 'dimplum', 'dimsalmon', 'dimteal', 'dimtomato', 'dimturquoise', 'dottedaqua', 'dottedbeige', 'dottedblack', 'dottedbrown', 'dottedchartreuse', 'dottedgold', 'dottedgray', 'dottedgreen', 'dottedindigo', 'dottedlime', 'dottedolive', 'dottedplum', 'dottedpurple', 'dottedred', 'dottedsilver', 'dottedteal', '