# %%
import pandas as pd
import numpy as np
import math
import re

# %%
filename = '../data/data.txt'  
with open(filename) as fn:  
    # Read each line
    ln = fn.readline()
    # Keep count of lines
    lncnt = 0
    validCounter=0
    totalCounter=0
    counter=0
    byr_flag = 0
    iyr_flag = 0
    eyr_flag = 0
    hgt_flag = 0
    hcl_flag = 0
    ecl_flag = 0
    pid_flag = 0
    cid_flag = 0
    while ln:
        x = ln.split(" ")
#         print(x[0]=="\n")
#         print("Line {}: {}".format(lncnt, ln.strip()))
        if (x[0]=="\n")==False:
            counter=counter+1
#             print(counter)
            if counter!=0:
                for i in range(0,len(x)):
                    b = x[i].split(":")
#                     print(b[0])
                    if b[0] == "byr":
#                         print("condition test",b[1],int(b[1])>=1920 and int(b[1])<=2002)
                        if int(b[1])>=1920 and int(b[1])<=2002:
                            byr_flag=byr_flag+1
                    elif b[0] == "iyr":
#                         print('condition test',b[1],int(b[1])>=2010 and int(b[1])<=2020)
                        if int(b[1])>=2010 and int(b[1])<=2020:
                            iyr_flag=iyr_flag+1
                    elif b[0] == "eyr":
#                         print('condition test',b[1],int(b[1])>=2020 and int(b[1])<=2030)
                        if int(b[1])>=2020 and int(b[1])<=2030:  
                            eyr_flag=eyr_flag+1
                    elif b[0] == "hgt":
#                         print("condition1 test",b[1],bool(re.match(r"([0-9]+)([a-z]+)", b[1], re.I)))
                        match = re.match(r"([0-9]+)([a-z]+)", b[1], re.I)
                        if match:
                            items = match.groups()
                            if items[1]=="in" and int(items[0])>=59 and int(items[0])<=76:
#                                 print("condition2 test inches",items[0],int(items[0])>=59 and int(items[0])<=76)
                                hgt_flag=hgt_flag+1
                            elif items[1]=="cm" and int(items[0])>=150 and int(items[0])<=193:
#                                 print("condition2 test cms",items[0],int(items[0])>=150 and int(items[0])<=193)
                                hgt_flag=hgt_flag+1
#                         print(items[0])
                    elif b[0] == "hcl": 
#                         print("condition 1",b[1],bool(re.match(r"([#])([A-Fa-f0-9]+)", b[1], re.I)))
#                         if len(b[1])==7:
                        match = re.match(r"([#])([A-Fa-f0-9]+)", b[1], re.I)
                        if match:
                            items = match.groups()
#                             print('condition2',items[1],len(items[1])==6)
                            if len(items[1])==6:
                                hcl_flag=hcl_flag+1
                    elif b[0] == "ecl":
                        print("condition 1",b[1],b[1] == "amb" or b[1] =="blu" or b[1] =="brn" or b[1] =="gry" or b[1] =="grn" or b[1] =="hzl" or b[1] =="oth")
                        if b[1] == "amb" or b[1] =="blu" or b[1] =="brn" or b[1] =="gry" or b[1] =="grn" or b[1] =="hzl" or b[1] =="oth":
                            ecl_flag=ecl_flag+1
                    elif b[0] == "pid":
                        if len(b[1])==9:
                            pid_flag=pid_flag+1
                    elif b[0] == "cid":
                        cid_flag=cid_flag+1
        else:
            test = byr_flag*iyr_flag*eyr_flag*hgt_flag*hcl_flag*ecl_flag*pid_flag
#             print("test Value:",test)
            if test ==1:
#                 print("valid")
                validCounter= validCounter+1
            totalCounter = totalCounter +1
            byr_flag = 0
            iyr_flag = 0
            eyr_flag = 0
            hgt_flag = 0
            hcl_flag = 0
            ecl_flag = 0
            pid_flag = 0
            cid_flag = 0
#             print("valid counter:",validCounter)
#             print("total counter :", totalCounter)

        ln = fn.readline()
        lncnt += 1
    print("valid counter:",validCounter)
    print("total counter :", totalCounter)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-326372b836c1> in <module>
#      61                                 hcl_flag=hcl_flag+1
#      62                     elif b[0] == "ecl":
# ---> 63                         print("condition 1",b[1],b[1] == amb or b[1] =="blu" or b[1] =="brn" or b[1] =="gry" or b[1] =="grn" or b[1] =="hzl" or b[1] =="oth")
#      64                         if b[1] == "amb" or b[1] =="blu" or b[1] =="brn" or b[1] =="gry" or b[1] =="grn" or b[1] =="hzl" or b[1] =="oth":
#      65                             ecl_flag=ecl_flag+1
#
# NameError: name 'amb' is not defined

# %%
# Out:
# ecl
# true
# pid
# false
# eyr
# false
# hcl
# false
# 1
# byr
# false
# iyr
# false
# cid
# false
# hgt
# false
# 2
# in loop2
# 0
# iyr
# false
# ecl
# true
# cid
# false
# eyr
# false
# pid
# false
# 1
# hcl
# false
# byr
# false
# 2
# in loop2
# 0
# hcl
# false
# iyr
# false
# 1
# eyr
# false
# 2
# ecl
# true
# pid
# false
# byr
# false
# 3
# hgt
# false
# 4
# in loop2
# 0
# hcl
# false
# eyr
# false
# pid
# false
# 1
# iyr
# false
# ecl
# true
# hgt
# false
# 2
